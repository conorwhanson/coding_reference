# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine, inspect, insert, update, select, Table, Column, Integer, String, MetaData
from config import username, pw, port, dbName, host

# %%
engine = create_engine(f"postgresql://{username}:{pw}@{host}:5432/{dbName}")

# %%
# conn = engine.connect()
inspectorGadg = inspect(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...

# %%
from aws_advanced_python_wrapper import AwsWrapperConnection
from psycopg2 import connect
from config import username, pw, port, dbName, host

# %%
awsconn = AwsWrapperConnection.connect(
        connect,
        f"host={host} dbname={dbName} user={username} password={pw} plugins=failover wrapper_dialect=pg"
)
